# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')

# %%
data = np.loadtxt('ts7895.txt') 
V1959t = data[:,0]
V1959m = data[:,1]

data = np.loadtxt('ts7912.txt') 
V1999t = data[:,0]
V1999m = data[:,1]

data = np.loadtxt('ts1791.txt') 
V2227t = data[:,0]
V2227m = data[:,1]

data = np.loadtxt('ts10860.txt') 
V2559t = data[:,0]
V2559m = data[:,1]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V1959t[0:20],V1959m[0:20],'bo')
fit=np.polyfit(V1959t[0:20],V1959m[0:20],1)
print(fit)
mfit=fit[0]*V1959t[0:20] + fit[1]
plt.plot(V1959t[0:20],mfit,'r-')
# Out:
# [-0.77547429  0.15371497]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V1959t[30:40],V1959m[30:40],'bo')
fit=np.polyfit(V1959t[30:40],V1959m[30:40],1)
print(fit)
mfit=fit[0]*V1959t[30:40] + fit[1]
plt.plot(V1959t[30:40],mfit,'r-')
# Out:
# [ 0.37001561 -0.40880564]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V1959t[90:],V1959m[90:],'bo')
fit=np.polyfit(V1959t[90:],V1959m[90:],1)
print(fit)
mfit=fit[0]*V1959t[90:] + fit[1]
plt.plot(V1959t[90:],mfit,'r-')
# Out:
# [ 0.37691252 -1.20528676]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V1999t[56:70],V1999m[56:70],'bo')
fit=np.polyfit(V1999t[56:70],V1999m[56:70],1)
print(fit)
mfit=fit[0]*V1999t[56:70] + fit[1]
plt.plot(V1999t[56:70],mfit,'r-')
# Out:
# [ 3.75606684 -7.63314909]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V1999t[100:],V1999m[100:],'bo')
fit=np.polyfit(V1999t[100:],V1999m[100:],1)
print(fit)
mfit=fit[0]*V1999t[100:] + fit[1]
plt.plot(V1999t[100:],mfit,'r-')
# Out:
# [ 2.46261829 -7.9392101 ]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V2559t[48:70],V2559m[48:70],'bo')
fit=np.polyfit(V2559t[48:70],V2559m[48:70],1)
print(fit)
mfit=fit[0]*V2559t[48:70] + fit[1]
plt.plot(V2559t[48:70],mfit,'r-')
# Out:
# [ 0.90441654 -1.38753778]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V2559t[80:90],V2559m[80:90],'bo')
fit=np.polyfit(V2559t[80:90],V2559m[80:90],1)
print(fit)
mfit=fit[0]*V2559t[80:90] + fit[1]
plt.plot(V2559t[80:90],mfit,'r-')
# Out:
# [-2.73254907  6.78864637]

# %%
fig = plt.figure(figsize=(8, 6))
plt.plot(V2227t[35:45],V2227m[35:45],'bo')
fit=np.polyfit(V2227t[35:45],V2227m[35:45],1)
print(fit)
mfit=fit[0]*V2227t[35:45] + fit[1]
plt.plot(V2227t[35:45],mfit,'r-')
# Out:
# [ 1.66173449 -1.83816907]

# %%
# %matplotlib inline
plt.rc('font', family='serif')
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize=15)
fig = plt.figure(figsize=(8, 6))
plt.xlim(np.min(cmd_ri_cal2)-0.1,np.max(cmd_ri_cal2)+0.1)
plt.ylim(np.max(cmd_r_cal2)+0.1,np.min(cmd_r_cal2)-0.1)
plt.xlabel('r-i (mag)',fontsize=20)
plt.ylabel('r (mag)',fontsize=20)
plt.title('V2559',fontsize=20)
#plt.scatter(cmd_ri_cal,cmd_r_cal,s=100)
plt.scatter(cmd_ri_cal2,cmd_r_cal2,s=100)
plt.errorbar(1.7,18.5,0.03,0.02,elinewidth=2,capsize=4)
